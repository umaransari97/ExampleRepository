# %% [markdown]
# <a href="https://colab.research.google.com/github/umaransari97/ExampleRepository/blob/master/FirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter any number: "))

for x in range(1, num + 1):
    if (num % x == 0 and x % 2 == 0):
        print(x, end=",")

# %% [markdown]
# Dictionary

# %%
x= set()
print(type(x))
y={} #dictionary
#MUTABLE, KEY - VALUE PAIR, ordered
print(type(y))
student = {
    "name": "Umar",
    "age": 20,
    "course": "BTech"
}  #dictionary
student['name']='rahul'; #updation
student['RollNo']=106;
student['college']='KNMIET'; #insertion

print(student)

# %%
student ={'name':'umar', 'roll': 106,'course':'B.Tech'}
for x in student:
  print(x+":",end='\t')
  print(student[x])
  #methods of dictionary
  #keys() return a lst of keys of dictionary

print(student.keys())

  # values() return a lsit of values of elements of dictionary
print(student.values())
  # items() return a list of elemetns in form of tuple
print(student.items())

# get(key, error message) return value of the provided key
print(student.get('a', "Not found"))

# %% [markdown]
# String Datatypes

# %%
#Collection of characters
#immutable
#enclosed within single, doublke or triple quotes
name= "umar"
print(len(name))
print(type(name))
for x in name:
  print(x)
#multiplication of string
print(name*4)
i=1;
while i<=5:
  print("*"*i)
  i=i+1
#printing in reverse order
n=int(input("Enter number of rows:"))
j=1
while j<=n:
  print(" "*(n-j)+"*"*j)
  j=j+1

# %% [markdown]
# Python Tutorial

# %%
x=5+3j
print(x)
#single lnie comment
""" multi
line
comment
 """
x="umar"
print(type(x))
print(id(x))
y=id(x)
print(type(y))
a1=32
a2=23
a3=342
print(a1,a2,a3,sep="_",end="\n")
print("umar ansar")
# Out:
# (5+3j)
# <class 'str'>
# 139907773323552
# <class 'int'>
# 32_23_342
# umar ansar

# %% [markdown]
# 7th April (Function)

# %%
#syntax of function
def function_name(a=234,b=0):
  return a+b;
print(function_name())
# Out:
# 234

# %%
#Calculation of simple interest
def calculate(R,P,T):
  return (P*R*T)/100

P=float(input("Enter principal amount:"))
R=float(input("Enter rate n percentage:"))
T=float(input("Enter time in year:"))
print("Simple interest :Rs",calculate(P,R,T));
print("Total amount:Rs",P+calculate(P,R,T))

# %% [markdown]
# Types of Parameter in function
# 1. Positional Parameter
# 2. Named parameter
# 3. Default
